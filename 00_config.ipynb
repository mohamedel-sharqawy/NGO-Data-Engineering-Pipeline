# %%
catalog_name = "workspace"
schema_name = "ngo_analytics"


spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog_name}.{schema_name}")


bronze_cases = f"{catalog_name}.{schema_name}.bronze_cases"
bronze_services = f"{catalog_name}.{schema_name}.bronze_services"

silver_cases = f"{catalog_name}.{schema_name}.silver_cases"
silver_services = f"{catalog_name}.{schema_name}.silver_services"

gold_daily_services = f"{catalog_name}.{schema_name}.gold_daily_services"
gold_case_360 = f"{catalog_name}.{schema_name}.gold_case_360"
gold_quality_summary = f"{catalog_name}.{schema_name}.gold_quality_summary"


raw_path = "/Volumes/workspace/default/raw_files/"
